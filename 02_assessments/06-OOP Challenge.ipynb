# %% [markdown]
# # Object Oriented Programming Challenge
#
# For this challenge, create a bank account class that has two attributes:
#
# * owner
# * balance
#
# and two methods:
#
# * deposit
# * withdraw
#
# As an added requirement, withdrawals may not exceed the available balance.
#
# Instantiate your class, make several deposits and withdrawals, and test to make sure the account can't be overdrawn.

# %%
class Account:
    def __init__(self, owner, balance =0):
        self.owner = owner
        self.balance = balance
        
    def __str__(self):
        return f"Account owner {self.owner}\nAccount balance {self.balance}"
        
    def deposit(self, deposit_amount):
        self.balance += deposit_amount
        print(f"Ypu have deosited {deposit_amount} sucessfully")
        
    def withdraw(self, withdraw_amount):
        self.balance -= withdraw_amount
        
        if self.balance < 0:
            raise ValueError("withdrawals may not exceeds the available balance")
        else:
            print(f"You have successfully withdraw amount of {withdraw_amount}")

# %%
# 1. Instantiate the class
acct1 = Account('Jose',100)

# %%
# 2. Print the object
print(acct1)
# Out:
# Account owner Jose
# Account balance 100

# %%
# 3. Show the account owner attribute
acct1.owner
# Out:
# 'Jose'

# %%
# 4. Show the account balance attribute
acct1.balance
# Out:
# 100

# %%
# 5. Make a series of deposits and withdrawals
acct1.deposit(50)
# Out:
# Ypu have deosited 50 sucessfully

# %%
acct1.withdraw(75)
# Out:
# You have successfully withdraw amount of 75

# %%
# 6. Make a withdrawal that exceeds the available balance
acct1.withdraw(500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 6. Make a withdrawal that exceeds the available balance
# ----> 2 acct1.withdraw(500)
#
# Cell In[5], line 17, in Account.withdraw(self, withdraw_amount)
#      14 self.balance -= withdraw_amount
#      16 if self.balance < 0:
# ---> 17     raise ValueError("withdrawals may not exceeds the available balance")
#      18 else:
#      19     print(f"You have successfully withdraw amount of {withdraw_amount}")
#
# ValueError: withdrawals may not exceeds the available balance

# %% [markdown]
# ## Good job!
